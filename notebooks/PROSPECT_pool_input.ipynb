# %% [markdown]
# *Experimental*
# __________
#
# ## Example Intesity Pipeline with PTMs using a PROSPECT POOL (Json Input)

# %% [markdown]
# ### Get the dataset from PROSPECT

# %%
# ensure a clean install in the environment if needed, uncomment the following line
# !pip uninstall dlomix prospect-dataset -y
# Out:
# Found existing installation: dlomix 0.0.5.dev0
# Uninstalling dlomix-0.0.5.dev0:
#   Successfully uninstalled dlomix-0.0.5.dev0
# Found existing installation: prospect-dataset 0.0.2.dev0
# Uninstalling prospect-dataset-0.0.2.dev0:
#   Successfully uninstalled prospect-dataset-0.0.2.dev0

# %%
# dlomix - develop version
# !pip install git+https://github.com/wilhelm-lab/dlomix.git@develop
# Out:
# Collecting git+https://github.com/wilhelm-lab/dlomix.git@develop
#   Cloning https://github.com/wilhelm-lab/dlomix.git (to revision develop) to /private/var/folders/cc/ny50w1ls59q3_l6sr7l5h3r40000gp/T/pip-req-build-mj_8xufe
#   Running command git clone --filter=blob:none --quiet https://github.com/wilhelm-lab/dlomix.git /private/var/folders/cc/ny50w1ls59q3_l6sr7l5h3r40000gp/T/pip-req-build-mj_8xufe
#   Running command git checkout -b develop --track origin/develop
#   Switched to a new branch 'develop'
#   branch 'develop' set up to track 'origin/develop'.
#   Resolved https://github.com/wilhelm-lab/dlomix.git to commit 72150a678b768bfe37489f0ba84713e3df1deed9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop (from dlomix==0.0.5.dev0)
#   Cloning https://github.com/wilhelm-lab/PROSPECT.git (to revision develop) to /private/var/folders/cc/ny50w1ls59q3_l6sr7l5h3r40000gp/T/pip-install-gz8mj0l3/prospect-dataset_44af8ca0286e44e4b4d4bae5ee20185d
#   Running command git clone --filter=blob:none --quiet https://github.com/wilhelm-lab/PROSPECT.git /private/var/folders/cc/ny50w1ls59q3_l6sr7l5h3r40000gp/T/pip-install-gz8mj0l3/prospect-dataset_44af8ca0286e44e4b4d4bae5ee20185d
#   Running command git checkout -b develop --track origin/develop
#   Switched to a new branch 'develop'
#   branch 'develop' set up to track 'origin/develop'.
#   Resolved https://github.com/wilhelm-lab/PROSPECT.git to commit e239d6259b7698efd0da874b858fbbbcfe9e10d2
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: fpdf in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from dlomix==0.0.5.dev0) (1.7.2)
# Requirement already satisfied: matplotlib in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from dlomix==0.0.5.dev0) (3.6.3)
# Requirement already satisfied: numpy in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from dlomix==0.0.5.dev0) (1.24.2)
# Requirement already satisfied: pandas in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from dlomix==0.0.5.dev0) (1.5.3)
# Requirement already satisfied: pyarrow in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from dlomix==0.0.5.dev0) (12.0.0)
# Requirement already satisfied: pyteomics[xml] in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from dlomix==0.0.5.dev0) (4.5.6)
# Requirement already satisfied: scikit-learn in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from dlomix==0.0.5.dev0) (1.2.1)
# Requirement already satisfied: seaborn in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from dlomix==0.0.5.dev0) (0.12.2)
# Requirement already satisfied: tensorflow-macos==2.10.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from dlomix==0.0.5.dev0) (2.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (23.5.9)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (3.6.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (15.0.6.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (3.3.0)
# Requirement already satisfied: packaging in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (23.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (3.19.6)
# Requirement already satisfied: setuptools in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (66.1.1)
# Requirement already satisfied: six>=1.12.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (4.6.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (1.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (1.46.3)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (2.10.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (2.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from matplotlib->dlomix==0.0.5.dev0) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from matplotlib->dlomix==0.0.5.dev0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from matplotlib->dlomix==0.0.5.dev0) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from matplotlib->dlomix==0.0.5.dev0) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from matplotlib->dlomix==0.0.5.dev0) (9.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from matplotlib->dlomix==0.0.5.dev0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from matplotlib->dlomix==0.0.5.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from pandas->dlomix==0.0.5.dev0) (2023.3)
# Collecting spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main (from prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0)
#   Cloning https://github.com/wilhelm-lab/spectrum_fundamentals.git (to revision main) to /private/var/folders/cc/ny50w1ls59q3_l6sr7l5h3r40000gp/T/pip-install-gz8mj0l3/spectrum-fundamentals_ad9d9b8f271e4429a42e42fbe90f45ab
#   Running command git clone --filter=blob:none --quiet https://github.com/wilhelm-lab/spectrum_fundamentals.git /private/var/folders/cc/ny50w1ls59q3_l6sr7l5h3r40000gp/T/pip-install-gz8mj0l3/spectrum-fundamentals_ad9d9b8f271e4429a42e42fbe90f45ab
#   Running command git checkout -b main --track origin/main
#   Switched to a new branch 'main'
#   branch 'main' set up to track 'origin/main'.
#   Resolved https://github.com/wilhelm-lab/spectrum_fundamentals.git to commit a0a8d21bb4196e5a968662664330935b1e512040
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: fastparquet in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (2023.1.0)
# Requirement already satisfied: requests in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (2.31.0)
# Requirement already satisfied: bs4 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (0.0.1)
# Requirement already satisfied: lxml in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from pyteomics[xml]->dlomix==0.0.5.dev0) (4.9.2)
# Requirement already satisfied: scipy>=1.3.2 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from scikit-learn->dlomix==0.0.5.dev0) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from scikit-learn->dlomix==0.0.5.dev0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from scikit-learn->dlomix==0.0.5.dev0) (3.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (2.16.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from tensorboard<2.11,>=2.10->tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from requests->prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from requests->prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from requests->prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from requests->prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (2023.5.7)
# Requirement already satisfied: beautifulsoup4 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from bs4->prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (4.12.2)
# Requirement already satisfied: cramjam>=2.3 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from fastparquet->prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (2.6.2)
# Requirement already satisfied: fsspec in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from fastparquet->prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (2023.1.0)
# Requirement already satisfied: PyYAML>=5.4.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (6.0)
# Requirement already satisfied: click>=8.0.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (8.1.3)
# Requirement already satisfied: moepy<2.0.0,>=1.1.4 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (1.1.4)
# Requirement already satisfied: rich>=10.3.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (13.3.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (6.6.0)
# Requirement already satisfied: tqdm>=4.59.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from moepy<2.0.0,>=1.1.4->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (4.65.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from rich>=10.3.0->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from rich>=10.3.0->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (2.15.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (2.1.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from beautifulsoup4->bs4->prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (2.3.2.post1)
# Requirement already satisfied: zipp>=0.5 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (3.15.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.3.0->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset@ git+https://github.com/wilhelm-lab/PROSPECT.git@develop->dlomix==0.0.5.dev0) (0.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-macos==2.10.0->dlomix==0.0.5.dev0) (3.2.2)
# Building wheels for collected packages: dlomix, prospect-dataset
#   Building wheel for dlomix (pyproject.toml) ... done
#   Created wheel for dlomix: filename=dlomix-0.0.5.dev0-py3-none-any.whl size=51100 sha256=d37a9740616de43728a14dcba0dbc7cf7a5f0b4e529bfbbc5567944825a048f2
#   Stored in directory: /private/var/folders/cc/ny50w1ls59q3_l6sr7l5h3r40000gp/T/pip-ephem-wheel-cache-at76tzcq/wheels/db/ee/d2/2aa9f1a015ebb51ddc87efa1bba43f622bca76e553eb1657d2
#   Building wheel for prospect-dataset (setup.py) ... done
#   Created wheel for prospect-dataset: filename=prospect_dataset-0.0.2.dev0-py3-none-any.whl size=20845 sha256=953ad17202985b16965b3e3223b2998aafafe164f05e145fe07fcf488e514100
#   Stored in directory: /private/var/folders/cc/ny50w1ls59q3_l6sr7l5h3r40000gp/T/pip-ephem-wheel-cache-at76tzcq/wheels/ca/23/e3/766cefcd9881ba2ecb5691f3acd4119716b034f48a993dd6f8
# Successfully built dlomix prospect-dataset
# Installing collected packages: prospect-dataset, dlomix
# Successfully installed dlomix-0.0.5.dev0 prospect-dataset-0.0.2.dev0

# %%
# PROSPECT
# !pip install git+https://github.com/wilhelm-lab/PROSPECT@develop
# Out:
# Collecting git+https://github.com/wilhelm-lab/PROSPECT@develop
#   Cloning https://github.com/wilhelm-lab/PROSPECT (to revision develop) to /private/var/folders/cc/ny50w1ls59q3_l6sr7l5h3r40000gp/T/pip-req-build-76rv7r8_
#   Running command git clone --filter=blob:none --quiet https://github.com/wilhelm-lab/PROSPECT /private/var/folders/cc/ny50w1ls59q3_l6sr7l5h3r40000gp/T/pip-req-build-76rv7r8_
#   Running command git checkout -b develop --track origin/develop
#   Switched to a new branch 'develop'
#   branch 'develop' set up to track 'origin/develop'.
#   Resolved https://github.com/wilhelm-lab/PROSPECT to commit e239d6259b7698efd0da874b858fbbbcfe9e10d2
#   Preparing metadata (setup.py) ... done
# Collecting spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main (from prospect-dataset==0.0.2.dev0)
#   Cloning https://github.com/wilhelm-lab/spectrum_fundamentals.git (to revision main) to /private/var/folders/cc/ny50w1ls59q3_l6sr7l5h3r40000gp/T/pip-install-ki965htz/spectrum-fundamentals_aebd51e093b14f0e95ffe47f8df293bf
#   Running command git clone --filter=blob:none --quiet https://github.com/wilhelm-lab/spectrum_fundamentals.git /private/var/folders/cc/ny50w1ls59q3_l6sr7l5h3r40000gp/T/pip-install-ki965htz/spectrum-fundamentals_aebd51e093b14f0e95ffe47f8df293bf
#   Running command git checkout -b main --track origin/main
#   Switched to a new branch 'main'
#   branch 'main' set up to track 'origin/main'.
#   Resolved https://github.com/wilhelm-lab/spectrum_fundamentals.git to commit a0a8d21bb4196e5a968662664330935b1e512040
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from prospect-dataset==0.0.2.dev0) (1.24.2)
# Requirement already satisfied: pandas in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from prospect-dataset==0.0.2.dev0) (1.5.3)
# Requirement already satisfied: fastparquet in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from prospect-dataset==0.0.2.dev0) (2023.1.0)
# Requirement already satisfied: pyarrow in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from prospect-dataset==0.0.2.dev0) (12.0.0)
# Requirement already satisfied: requests in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from prospect-dataset==0.0.2.dev0) (2.31.0)
# Requirement already satisfied: bs4 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from prospect-dataset==0.0.2.dev0) (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from bs4->prospect-dataset==0.0.2.dev0) (4.12.2)
# Requirement already satisfied: cramjam>=2.3 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from fastparquet->prospect-dataset==0.0.2.dev0) (2.6.2)
# Requirement already satisfied: fsspec in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from fastparquet->prospect-dataset==0.0.2.dev0) (2023.1.0)
# Requirement already satisfied: packaging in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from fastparquet->prospect-dataset==0.0.2.dev0) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from pandas->prospect-dataset==0.0.2.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from pandas->prospect-dataset==0.0.2.dev0) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from requests->prospect-dataset==0.0.2.dev0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from requests->prospect-dataset==0.0.2.dev0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from requests->prospect-dataset==0.0.2.dev0) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from requests->prospect-dataset==0.0.2.dev0) (2023.5.7)
# Requirement already satisfied: PyYAML>=5.4.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (6.0)
# Requirement already satisfied: click>=8.0.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (8.1.3)
# Requirement already satisfied: joblib<2.0.0,>=1.0.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (1.2.0)
# Requirement already satisfied: moepy<2.0.0,>=1.1.4 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (1.1.4)
# Requirement already satisfied: rich>=10.3.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (13.3.5)
# Requirement already satisfied: scikit-learn<2.0,>=1.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (1.2.1)
# Requirement already satisfied: matplotlib>=3.3.3 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from moepy<2.0.0,>=1.1.4->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (3.6.3)
# Requirement already satisfied: tqdm>=4.59.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from moepy<2.0.0,>=1.1.4->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (4.65.0)
# Requirement already satisfied: scipy>=1.6.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from moepy<2.0.0,>=1.1.4->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (1.10.1)
# Requirement already satisfied: six>=1.5 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->prospect-dataset==0.0.2.dev0) (1.15.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from rich>=10.3.0->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from rich>=10.3.0->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (2.15.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from rich>=10.3.0->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (4.6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from scikit-learn<2.0,>=1.0->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (3.1.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from beautifulsoup4->bs4->prospect-dataset==0.0.2.dev0) (2.3.2.post1)
# Requirement already satisfied: mdurl~=0.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.3.0->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (0.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from matplotlib>=3.3.3->moepy<2.0.0,>=1.1.4->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from matplotlib>=3.3.3->moepy<2.0.0,>=1.1.4->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from matplotlib>=3.3.3->moepy<2.0.0,>=1.1.4->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from matplotlib>=3.3.3->moepy<2.0.0,>=1.1.4->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from matplotlib>=3.3.3->moepy<2.0.0,>=1.1.4->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (9.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/Omar/miniforge3/envs/dlomix/lib/python3.8/site-packages (from matplotlib>=3.3.3->moepy<2.0.0,>=1.1.4->spectrum_fundamentals@ git+https://github.com/wilhelm-lab/spectrum_fundamentals.git@main->prospect-dataset==0.0.2.dev0) (3.0.9)

# %%
import prospectdataset as prospect 
data_dir = "./data"
pool_keyword = "first_pool"
record_name = "prospect"
prospect.download_dataset(record = record_name, task = "all",
                          save_directory = data_dir, select_pool = pool_keyword)
# Out:
# Downloading dataset from Zenodo record prospect
# Corresponding Zenodo URL is https://zenodo.org/record/6602020
# Collected URLs:  ['/record/6602020/files/TUM_first_pool_1.zip?download=1', '/record/6602020/files/TUM_first_pool_2.zip?download=1', '/record/6602020/files/TUM_first_pool_3.zip?download=1', '/record/6602020/files/TUM_first_pool_meta_data.parquet?download=1']
# Downloading URL:  /record/6602020/files/TUM_first_pool_1.zip?download=1
# Saved file:  ./data/TUM_first_pool_1.zip
# Downloading URL:  /record/6602020/files/TUM_first_pool_2.zip?download=1
# Saved file:  ./data/TUM_first_pool_2.zip
# Downloading URL:  /record/6602020/files/TUM_first_pool_3.zip?download=1
# Saved file:  ./data/TUM_first_pool_3.zip
# Downloading URL:  /record/6602020/files/TUM_first_pool_meta_data.parquet?download=1
# Saved file:  ./data/TUM_first_pool_meta_data.parquet
# Unzipping file ./data/TUM_first_pool_1.zip
# Unzipping file ./data/TUM_first_pool_2.zip
# Unzipping file ./data/TUM_first_pool_3.zip
# [['./data/TUM_first_pool_1.zip',
#   './data/TUM_first_pool_2.zip',
#   './data/TUM_first_pool_3.zip',
#   './data/TUM_first_pool_meta_data.parquet']]

# %%
import glob
import os
from pathlib import Path

# pick the path of the metadata file, can also be simply copied and pasted from previous cell outout 
#meta_data_filepath = './data/TUM_third_pool_meta_data.parquet'

meta_data_filepath = glob.glob(os.path.join(data_dir, "*"+str(pool_keyword)+"*meta_data.parquet"))[0]
meta_data_filepath
# Out:
# './data/TUM_first_pool_meta_data.parquet'

# %%
import itertools

annotation_dirs = [path for path in glob.glob(os.path.join(data_dir, "*"+str(pool_keyword)+"*")) if os.path.isdir(path)]
annotations_filepaths = [glob.glob(os.path.join(d, "*.parquet")) for d in annotation_dirs]
annotations_filepaths = list(itertools.chain(*annotations_filepaths))
annotations_names = [Path(f).stem for f in annotations_filepaths]

annotations_names, annotations_filepaths
# Out:
# (['TUM_first_pool_6_01_01_annotation',
#   'TUM_first_pool_51_01_01_annotation',
#   'TUM_first_pool_66_01_01_annotation',
#   'TUM_first_pool_2_01_01_annotation',
#   'TUM_first_pool_88_01_01_annotation',
#   'TUM_first_pool_62_01_01_annotation',
#   'TUM_first_pool_55_01_01_annotation',
#   'TUM_first_pool_112_01_01_annotation',
#   'TUM_first_pool_37_01_01_annotation',
#   'TUM_first_pool_59_01_01_annotation',
#   'TUM_first_pool_84_01_01_annotation',
#   'TUM_first_pool_116_01_01_annotation',
#   'TUM_first_pool_121_01_01_annotation',
#   'TUM_first_pool_33_01_01_annotation',
#   'TUM_first_pool_80_01_01_annotation',
#   'TUM_first_pool_74_01_01_annotation',
#   'TUM_first_pool_43_01_01_annotation',
#   'TUM_first_pool_108_01_01_annotation',
#   'TUM_first_pool_47_01_01_annotation',
#   'TUM_first_pool_70_01_01_annotation',
#   'TUM_first_pool_29_01_01_annotation',
#   'TUM_first_pool_25_01_01_annotation',
#   'TUM_first_pool_12_01_01_annotation',
#   'TUM_first_pool_96_01_01_annotation',
#   'TUM_first_pool_100_01_01_annotation',
#   'TUM_first_pool_16_01_01_annotation',
#   'TUM_first_pool_21_01_01_annotation',
#   'TUM_first_pool_78_01_01_annotation',
#   'TUM_first_pool_92_01_01_annotation',
#   'TUM_first_pool_104_01_01_annotation',
#   'TUM_first_pool_46_01_01_annotation',
#   'TUM_first_pool_71_01_01_annotation',
#   'TUM_first_pool_28_01_01_annotation',
#   'TUM_first_pool_109_01_01_annotation',
#   'TUM_first_pool_75_01_01_annotation',
#   'TUM_first_pool_42_01_01_annotation',
#   'TUM_first_pool_105_01_01_annotation',
#   'TUM_first_pool_93_01_01_annotation',
#   'TUM_first_pool_17_01_01_annotation',
#   'TUM_first_pool_20_01_01_annotation',
#   'TUM_first_pool_79_01_01_annotation',
#   'TUM_first_pool_101_01_01_annotation',
#   'TUM_first_pool_97_01_01_annotation',
#   'TUM_first_pool_24_01_01_annotation',
#   'TUM_first_pool_13_01_01_annotation',
#   'TUM_first_pool_63_01_01_annotation',
#   'TUM_first_pool_54_01_01_annotation',
#   'TUM_first_pool_89_01_01_annotation',
#   'TUM_first_pool_3_01_01_annotation',
#   'TUM_first_pool_50_01_01_annotation',
#   'TUM_first_pool_67_01_01_annotation',
#   'TUM_first_pool_7_01_01_annotation',
#   'TUM_first_pool_81_01_01_annotation',
#   'TUM_first_pool_32_01_01_annotation',
#   'TUM_first_pool_117_01_01_annotation',
#   'TUM_first_pool_120_01_01_annotation',
#   'TUM_first_pool_85_01_01_annotation',
#   'TUM_first_pool_36_01_01_annotation',
#   'TUM_first_pool_58_01_01_annotation',
#   'TUM_first_pool_113_01_01_annotation',
#   'TUM_first_pool_95_01_01_annotation',
#   'TUM_first_pool_48_01_01_annotation',
#   'TUM_first_pool_26_01_01_annotation',
#   'TUM_first_pool_11_01_01_annotation',
#   'TUM_first_pool_103_01_01_annotation',
#   'TUM_first_pool_91_01_01_annotation',
#   'TUM_first_pool_15_01_01_annotation',
#   'TUM_first_pool_22_01_01_annotation',
#   'TUM_first_pool_107_01_01_annotation',
#   'TUM_first_pool_19_01_01_annotation',
#   'TUM_first_pool_77_01_01_annotation',
#   'TUM_first_pool_40_01_01_annotation',
#   'TUM_first_pool_44_01_01_annotation',
#   'TUM_first_pool_73_01_01_annotation',
#   'TUM_first_pool_99_01_01_annotation',
#   'TUM_first_pool_111_01_01_annotation',
#   'TUM_first_pool_87_01_01_annotation',
#   'TUM_first_pool_34_01_01_annotation',
#   'TUM_first_pool_115_01_01_annotation',
#   'TUM_first_pool_122_01_01_annotation',
#   'TUM_first_pool_9_01_01_annotation',
#   'TUM_first_pool_83_01_01_annotation',
#   'TUM_first_pool_69_01_01_annotation',
#   'TUM_first_pool_30_01_01_annotation',
#   'TUM_first_pool_119_01_01_annotation',
#   'TUM_first_pool_5_01_01_annotation',
#   'TUM_first_pool_52_01_01_annotation',
#   'TUM_first_pool_65_01_01_annotation',
#   'TUM_first_pool_1_01_01_annotation',
#   'TUM_first_pool_38_01_01_annotation',
#   'TUM_first_pool_61_01_01_annotation',
#   'TUM_first_pool_56_01_01_annotation',
#   'TUM_first_pool_68_01_01_annotation',
#   'TUM_first_pool_31_01_01_annotation',
#   'TUM_first_pool_82_01_01_annotation',
#   'TUM_first_pool_114_01_01_annotation',
#   'TUM_first_pool_123_01_01_annotation',
#   'TUM_first_pool_8_01_01_annotation',
#   'TUM_first_pool_35_01_01_annotation',
#   'TUM_first_pool_86_01_01_annotation',
#   'TUM_first_pool_110_01_01_annotation',
#   'TUM_first_pool_39_01_01_annotation',
#   'TUM_first_pool_60_01_01_annotation',
#   'TUM_first_pool_57_01_01_annotation',
#   'TUM_first_pool_53_01_01_annotation',
#   'TUM_first_pool_64_01_01_annotation',
#   'TUM_first_pool_118_01_01_annotation',
#   'TUM_first_pool_4_01_01_annotation',
#   'TUM_first_pool_106_01_01_annotation',
#   'TUM_first_pool_14_01_01_annotation',
#   'TUM_first_pool_23_01_01_annotation',
#   'TUM_first_pool_90_01_01_annotation',
#   'TUM_first_pool_102_01_01_annotation',
#   'TUM_first_pool_49_01_01_annotation',
#   'TUM_first_pool_27_01_01_annotation',
#   'TUM_first_pool_10_01_01_annotation',
#   'TUM_first_pool_94_01_01_annotation',
#   'TUM_first_pool_98_01_01_annotation',
#   'TUM_first_pool_45_01_01_annotation',
#   'TUM_first_pool_72_01_01_annotation',
#   'TUM_first_pool_18_01_01_annotation',
#   'TUM_first_pool_76_01_01_annotation',
#   'TUM_first_pool_41_01_01_annotation'],
#  ['./data/TUM_first_pool/TUM_first_pool_6_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_51_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_66_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_2_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_88_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_62_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_55_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_112_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_37_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_59_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_84_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_116_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_121_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_33_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_80_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_74_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_43_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_108_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_47_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_70_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_29_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_25_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_12_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_96_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_100_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_16_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_21_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_78_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_92_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_104_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_46_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_71_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_28_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_109_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_75_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_42_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_105_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_93_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_17_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_20_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_79_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_101_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_97_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_24_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_13_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_63_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_54_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_89_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_3_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_50_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_67_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_7_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_81_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_32_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_117_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_120_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_85_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_36_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_58_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_113_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_95_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_48_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_26_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_11_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_103_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_91_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_15_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_22_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_107_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_19_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_77_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_40_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_44_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_73_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_99_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_111_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_87_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_34_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_115_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_122_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_9_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_83_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_69_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_30_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_119_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_5_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_52_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_65_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_1_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_38_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_61_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_56_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_68_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_31_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_82_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_114_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_123_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_8_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_35_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_86_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_110_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_39_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_60_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_57_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_53_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_64_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_118_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_4_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_106_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_14_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_23_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_90_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_102_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_49_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_27_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_10_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_94_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_98_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_45_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_72_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_18_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_76_01_01_annotation.parquet',
#   './data/TUM_first_pool/TUM_first_pool_41_01_01_annotation.parquet'])

# %% [markdown]
# ### Prepare input data dict for DLOmix Dataset Class (JSON mode)

# %%
input_data_dict = {
    "metadata": meta_data_filepath,
    "annotations": {
        pool_keyword: dict(zip(annotations_names, annotations_filepaths))
    },
    "parameters": {
        "target_column_key": "intensities_raw"
    }
}

input_data_dict
# Out:
# {'metadata': './data/TUM_first_pool_meta_data.parquet',
#  'annotations': {'first_pool': {'TUM_first_pool_6_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_6_01_01_annotation.parquet',
#    'TUM_first_pool_51_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_51_01_01_annotation.parquet',
#    'TUM_first_pool_66_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_66_01_01_annotation.parquet',
#    'TUM_first_pool_2_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_2_01_01_annotation.parquet',
#    'TUM_first_pool_88_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_88_01_01_annotation.parquet',
#    'TUM_first_pool_62_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_62_01_01_annotation.parquet',
#    'TUM_first_pool_55_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_55_01_01_annotation.parquet',
#    'TUM_first_pool_112_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_112_01_01_annotation.parquet',
#    'TUM_first_pool_37_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_37_01_01_annotation.parquet',
#    'TUM_first_pool_59_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_59_01_01_annotation.parquet',
#    'TUM_first_pool_84_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_84_01_01_annotation.parquet',
#    'TUM_first_pool_116_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_116_01_01_annotation.parquet',
#    'TUM_first_pool_121_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_121_01_01_annotation.parquet',
#    'TUM_first_pool_33_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_33_01_01_annotation.parquet',
#    'TUM_first_pool_80_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_80_01_01_annotation.parquet',
#    'TUM_first_pool_74_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_74_01_01_annotation.parquet',
#    'TUM_first_pool_43_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_43_01_01_annotation.parquet',
#    'TUM_first_pool_108_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_108_01_01_annotation.parquet',
#    'TUM_first_pool_47_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_47_01_01_annotation.parquet',
#    'TUM_first_pool_70_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_70_01_01_annotation.parquet',
#    'TUM_first_pool_29_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_29_01_01_annotation.parquet',
#    'TUM_first_pool_25_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_25_01_01_annotation.parquet',
#    'TUM_first_pool_12_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_12_01_01_annotation.parquet',
#    'TUM_first_pool_96_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_96_01_01_annotation.parquet',
#    'TUM_first_pool_100_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_100_01_01_annotation.parquet',
#    'TUM_first_pool_16_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_16_01_01_annotation.parquet',
#    'TUM_first_pool_21_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_21_01_01_annotation.parquet',
#    'TUM_first_pool_78_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_78_01_01_annotation.parquet',
#    'TUM_first_pool_92_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_92_01_01_annotation.parquet',
#    'TUM_first_pool_104_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_104_01_01_annotation.parquet',
#    'TUM_first_pool_46_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_46_01_01_annotation.parquet',
#    'TUM_first_pool_71_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_71_01_01_annotation.parquet',
#    'TUM_first_pool_28_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_28_01_01_annotation.parquet',
#    'TUM_first_pool_109_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_109_01_01_annotation.parquet',
#    'TUM_first_pool_75_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_75_01_01_annotation.parquet',
#    'TUM_first_pool_42_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_42_01_01_annotation.parquet',
#    'TUM_first_pool_105_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_105_01_01_annotation.parquet',
#    'TUM_first_pool_93_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_93_01_01_annotation.parquet',
#    'TUM_first_pool_17_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_17_01_01_annotation.parquet',
#    'TUM_first_pool_20_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_20_01_01_annotation.parquet',
#    'TUM_first_pool_79_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_79_01_01_annotation.parquet',
#    'TUM_first_pool_101_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_101_01_01_annotation.parquet',
#    'TUM_first_pool_97_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_97_01_01_annotation.parquet',
#    'TUM_first_pool_24_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_24_01_01_annotation.parquet',
#    'TUM_first_pool_13_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_13_01_01_annotation.parquet',
#    'TUM_first_pool_63_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_63_01_01_annotation.parquet',
#    'TUM_first_pool_54_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_54_01_01_annotation.parquet',
#    'TUM_first_pool_89_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_89_01_01_annotation.parquet',
#    'TUM_first_pool_3_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_3_01_01_annotation.parquet',
#    'TUM_first_pool_50_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_50_01_01_annotation.parquet',
#    'TUM_first_pool_67_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_67_01_01_annotation.parquet',
#    'TUM_first_pool_7_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_7_01_01_annotation.parquet',
#    'TUM_first_pool_81_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_81_01_01_annotation.parquet',
#    'TUM_first_pool_32_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_32_01_01_annotation.parquet',
#    'TUM_first_pool_117_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_117_01_01_annotation.parquet',
#    'TUM_first_pool_120_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_120_01_01_annotation.parquet',
#    'TUM_first_pool_85_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_85_01_01_annotation.parquet',
#    'TUM_first_pool_36_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_36_01_01_annotation.parquet',
#    'TUM_first_pool_58_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_58_01_01_annotation.parquet',
#    'TUM_first_pool_113_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_113_01_01_annotation.parquet',
#    'TUM_first_pool_95_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_95_01_01_annotation.parquet',
#    'TUM_first_pool_48_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_48_01_01_annotation.parquet',
#    'TUM_first_pool_26_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_26_01_01_annotation.parquet',
#    'TUM_first_pool_11_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_11_01_01_annotation.parquet',
#    'TUM_first_pool_103_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_103_01_01_annotation.parquet',
#    'TUM_first_pool_91_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_91_01_01_annotation.parquet',
#    'TUM_first_pool_15_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_15_01_01_annotation.parquet',
#    'TUM_first_pool_22_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_22_01_01_annotation.parquet',
#    'TUM_first_pool_107_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_107_01_01_annotation.parquet',
#    'TUM_first_pool_19_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_19_01_01_annotation.parquet',
#    'TUM_first_pool_77_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_77_01_01_annotation.parquet',
#    'TUM_first_pool_40_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_40_01_01_annotation.parquet',
#    'TUM_first_pool_44_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_44_01_01_annotation.parquet',
#    'TUM_first_pool_73_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_73_01_01_annotation.parquet',
#    'TUM_first_pool_99_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_99_01_01_annotation.parquet',
#    'TUM_first_pool_111_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_111_01_01_annotation.parquet',
#    'TUM_first_pool_87_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_87_01_01_annotation.parquet',
#    'TUM_first_pool_34_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_34_01_01_annotation.parquet',
#    'TUM_first_pool_115_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_115_01_01_annotation.parquet',
#    'TUM_first_pool_122_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_122_01_01_annotation.parquet',
#    'TUM_first_pool_9_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_9_01_01_annotation.parquet',
#    'TUM_first_pool_83_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_83_01_01_annotation.parquet',
#    'TUM_first_pool_69_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_69_01_01_annotation.parquet',
#    'TUM_first_pool_30_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_30_01_01_annotation.parquet',
#    'TUM_first_pool_119_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_119_01_01_annotation.parquet',
#    'TUM_first_pool_5_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_5_01_01_annotation.parquet',
#    'TUM_first_pool_52_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_52_01_01_annotation.parquet',
#    'TUM_first_pool_65_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_65_01_01_annotation.parquet',
#    'TUM_first_pool_1_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_1_01_01_annotation.parquet',
#    'TUM_first_pool_38_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_38_01_01_annotation.parquet',
#    'TUM_first_pool_61_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_61_01_01_annotation.parquet',
#    'TUM_first_pool_56_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_56_01_01_annotation.parquet',
#    'TUM_first_pool_68_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_68_01_01_annotation.parquet',
#    'TUM_first_pool_31_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_31_01_01_annotation.parquet',
#    'TUM_first_pool_82_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_82_01_01_annotation.parquet',
#    'TUM_first_pool_114_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_114_01_01_annotation.parquet',
#    'TUM_first_pool_123_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_123_01_01_annotation.parquet',
#    'TUM_first_pool_8_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_8_01_01_annotation.parquet',
#    'TUM_first_pool_35_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_35_01_01_annotation.parquet',
#    'TUM_first_pool_86_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_86_01_01_annotation.parquet',
#    'TUM_first_pool_110_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_110_01_01_annotation.parquet',
#    'TUM_first_pool_39_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_39_01_01_annotation.parquet',
#    'TUM_first_pool_60_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_60_01_01_annotation.parquet',
#    'TUM_first_pool_57_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_57_01_01_annotation.parquet',
#    'TUM_first_pool_53_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_53_01_01_annotation.parquet',
#    'TUM_first_pool_64_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_64_01_01_annotation.parquet',
#    'TUM_first_pool_118_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_118_01_01_annotation.parquet',
#    'TUM_first_pool_4_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_4_01_01_annotation.parquet',
#    'TUM_first_pool_106_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_106_01_01_annotation.parquet',
#    'TUM_first_pool_14_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_14_01_01_annotation.parquet',
#    'TUM_first_pool_23_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_23_01_01_annotation.parquet',
#    'TUM_first_pool_90_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_90_01_01_annotation.parquet',
#    'TUM_first_pool_102_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_102_01_01_annotation.parquet',
#    'TUM_first_pool_49_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_49_01_01_annotation.parquet',
#    'TUM_first_pool_27_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_27_01_01_annotation.parquet',
#    'TUM_first_pool_10_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_10_01_01_annotation.parquet',
#    'TUM_first_pool_94_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_94_01_01_annotation.parquet',
#    'TUM_first_pool_98_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_98_01_01_annotation.parquet',
#    'TUM_first_pool_45_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_45_01_01_annotation.parquet',
#    'TUM_first_pool_72_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_72_01_01_annotation.parquet',
#    'TUM_first_pool_18_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_18_01_01_annotation.parquet',
#    'TUM_first_pool_76_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_76_01_01_annotation.parquet',
#    'TUM_first_pool_41_01_01_annotation': './data/TUM_first_pool/TUM_first_pool_41_01_01_annotation.parquet'}},
#  'parameters': {'target_column_key': 'intensities_raw'}}

# %%
# later we can feed the dict directly as a data source, for now we stick to json format

import json
with open("input_config.json", 'w') as fp:
    json.dump(input_data_dict, fp)

# %% [markdown]
# ### Create Intensity Dataset from the downloaded Pool using features and parser
# This would take a couple of minutes since it:
# - reads the metadata and the annotation files
# - does some filtering and wrangling of the data
# - produces the final input data for intensity
# - extracts the features and prepares the TensorFlow Datasets

# %%
from dlomix.data import IntensityDataset
from dlomix.data.feature_extractors import (
    ModificationGainFeature,
    ModificationLocationFeature,
    ModificationLossFeature,
)

BATCH_SIZE = 128
SEQ_LENGTH = 30

int_data = IntensityDataset(
    data_source="input_config.json",
    seq_length=SEQ_LENGTH,
    batch_size=BATCH_SIZE,
    val_ratio=0.15,
    precursor_charge_col="precursor_charge_onehot",
    sequence_col="modified_sequence",
    collision_energy_col="collision_energy_aligned_normed",
    intensities_col="intensities_raw",
    features_to_extract=[
        ModificationLocationFeature(),
        ModificationLossFeature(),
        ModificationGainFeature(),
    ],
    parser="proforma",
    sequence_filtering_criteria = {
        "max_peptide_length": SEQ_LENGTH,
        "max_precursor_charge": 6,
    }
)
# Out:
# Optionally Downloading and processing the data...
# Annotations directory:  /Users/Omar/Documents/VSCode_repos/dlomix/dlomix/notebooks/./data/TUM_first_pool
# Metadata filepath:  /Users/Omar/Documents/VSCode_repos/dlomix/dlomix/notebooks/./data/TUM_first_pool_meta_data.parquet
# Base directory:  /Users/Omar/Documents/VSCode_repos/dlomix/dlomix/notebooks
# Reading metadata file from /Users/Omar/Documents/VSCode_repos/dlomix/dlomix/notebooks/./data/TUM_first_pool_meta_data.parquet
# Reading and processing annotation files...
# Building annotation dataframe...
# Applying metadata filters...
# mode:  max
# attribute:  peptide_length
# mode:  max
# attribute:  precursor_charge
# Scaling and adding encoded columns...
# Extracting feature:  ModificationLocationFeature(pad_to_seq_length=True, padding_element=-1)
# Extracting feature:  ModificationLossFeature(pad_to_seq_length=True, padding_element=[0, 0, 0, 0, 0, 0])
# Extracting feature:  ModificationGainFeature(pad_to_seq_length=True, padding_element=[0, 0, 0, 0, 0, 0])

# %%
"Training examples", BATCH_SIZE * len(int_data.train_data)
# Out:
# ('Training examples', 8396672)

# %%
"Validation examples", BATCH_SIZE * len(int_data.val_data)
# Out:
# ('Validation examples', 1481856)

# %% [markdown]
# ### Create Model and compile it with the respective loss

# %%
import tensorflow as tf
from dlomix.models import PrositIntensityPredictor
from dlomix.losses import masked_spectral_distance

model = PrositIntensityPredictor(seq_length=30, use_ptm_counts=False)

# create the optimizer object
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# compile the model  with the optimizer and the metrics we want to use, we can add our custom metric
model.compile(optimizer=optimizer, loss=masked_spectral_distance, metrics=["mae"])

# %% [markdown]
# ### Train model

# %%
history = model.fit(int_data.train_data,
                    validation_data=int_data.val_data,
                    epochs=2)
# Out:
# Epoch 1/2
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=[<tf.Tensor 'prosit_intensity_predictor/Cast:0' shape=(None, 1) dtype=float32>, <tf.Tensor 'IteratorGetNext:4' shape=(None, 6) dtype=float32>]. Consider rewriting this model with the Functional API.
# 2023-06-24 22:05:57.738395: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=[<tf.Tensor 'prosit_intensity_predictor/encoder_att/Sum_1:0' shape=(None, 512) dtype=float32>, <tf.Tensor 'prosit_intensity_predictor/sequential/meta_dense_do/dropout/Mul_1:0' shape=(None, 512) dtype=float32>]. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=[<tf.Tensor 'prosit_intensity_predictor/Cast:0' shape=(None, 1) dtype=float32>, <tf.Tensor 'IteratorGetNext:4' shape=(None, 6) dtype=float32>]. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=[<tf.Tensor 'prosit_intensity_predictor/encoder_att/Sum_1:0' shape=(None, 512) dtype=float32>, <tf.Tensor 'prosit_intensity_predictor/sequential/meta_dense_do/dropout/Mul_1:0' shape=(None, 512) dtype=float32>]. Consider rewriting this model with the Functional API.
#    19/65599 [..............................] - ETA: 6:42:04 - loss: 0.5720 - mae: 0.8136
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 history = model.fit(int_data.train_data,
#       2                     validation_data=int_data.val_data,
#       3                     epochs=2)
#
# File ~/miniforge3/envs/dlomix/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/dlomix/lib/python3.8/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~/miniforge3/envs/dlomix/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/dlomix/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniforge3/envs/dlomix/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/miniforge3/envs/dlomix/lib/python3.8/site-packages/tensorflow/python/eager/function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniforge3/envs/dlomix/lib/python3.8/site-packages/tensorflow/python/eager/function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniforge3/envs/dlomix/lib/python3.8/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/miniforge3/envs/dlomix/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:
