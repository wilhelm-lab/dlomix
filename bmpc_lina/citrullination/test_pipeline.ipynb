# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from dlomix.interface import load_keras_model, process_dataset
from dlomix.losses import masked_spectral_distance
# Out:
# 2024-08-24 14:34:46.155877: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-24 14:34:46.155934: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-24 14:34:46.236938: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-24 14:34:46.296477: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = '0'

# %%
from oktoberfest.runner import run_job
runner = run_job('/nfs/home/students/l.willruth/mapra/dlomix/bmpc_lina/citrullination/citrullination_configs/ce_calibration_citrullination_data2.config.json')
# Out:
# 2024-08-19 14:30:32,001 - INFO - oktoberfest.utils.config::read Reading configuration from /nfs/home/students/l.willruth/mapra/dlomix/bmpc_lina/citrullination/citrullination_configs/ce_calibration_citrullination_data2.config.json
# 2024-08-19 14:30:32,009 - INFO - oktoberfest.runner::run_job Oktoberfest version 0.7.0
# Copyright 2024, Wilhelmlab at Technical University of Munich
# 2024-08-19 14:30:32,010 - INFO - oktoberfest.runner::run_job Job executed with the following config:
# 2024-08-19 14:30:32,012 - INFO - oktoberfest.runner::run_job {
#     "type": "CollisionEnergyCalibration",
#     "tag": "",
#     "inputs": {
#         "search_results": "/cmnfs/data/proteomics/MQ_cit_LeeLab/MQ100%/msms.txt",
#         "search_results_type": "Maxquant",
#         "spectra": "/cmnfs/data/proteomics/MQ_cit_LeeLab/mzML/",
#         "spectra_type": "mzML",
#         "custom_modifications": {
#             "var_mods": {
#                 "R(ci)": [
#                     7,
# ...

# %%
runner = run_job('/nfs/home/students/l.willruth/mapra/dlomix/bmpc_lina/citrullination/citrullination_configs/tl_citrullination_data2.config.json')
# Out:
# 2024-08-18 15:03:00,277 - INFO - oktoberfest.utils.config::read Reading configuration from /nfs/home/students/l.willruth/mapra/dlomix/bmpc_lina/citrullination/citrullination_configs/tl_citrullination_data2.config.json
# 2024-08-18 15:03:00,284 - INFO - oktoberfest.runner::run_job Oktoberfest version 0.7.0
# Copyright 2024, Wilhelmlab at Technical University of Munich
# 2024-08-18 15:03:00,286 - INFO - oktoberfest.runner::run_job Job executed with the following config:
# 2024-08-18 15:03:00,287 - INFO - oktoberfest.runner::run_job {
#     "type": "Rescoring",
#     "tag": "",
#     "inputs": {
#         "search_results": "/cmnfs/data/proteomics/MQ_cit_LeeLab/MQ100%/msms.txt",
#         "search_results_type": "Maxquant",
#         "spectra": "/cmnfs/data/proteomics/MQ_cit_LeeLab/mzML/",
#         "spectra_type": "mzML",
#         "custom_modifications": {
#             "var_mods": {
#                 "R(ci)": [
#                     7,
#                     0.984016,
# ...

# %%
run_job()
